# %% [markdown]
# #### Connect to the database
# Load the ipython-sql extension and establish a connection with the database

# %%
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompatible)
# !pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# !pip install ipython-sql
# Out:
# ...
#   Using cached ibm_db-3.1.0-py3-none-any.whl
# ...
#   Using cached ibm_db_sa-0.3.3-py3-none-any.whl
# ...
#   Using cached SQLAlchemy-1.4.36-cp38-cp38-win_amd64.whl (1.6 MB)
# ...
#   Using cached greenlet-1.1.2-cp38-cp38-win_amd64.whl (101 kB)
# ...
#   Attempting uninstall: ibm_db
#     Found existing installation: ibm-db 3.1.0
#     Uninstalling ibm-db-3.1.0:
#       Successfully uninstalled ibm-db-3.1.0
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 1.1.2
#     Uninstalling greenlet-1.1.2:
#       Successfully uninstalled greenlet-1.1.2
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.24
#     Uninstalling SQLAlchemy-1.3.24:
#       Successfully uninstalled SQLAlchemy-1.3.24
#   Attempting uninstall: ibm_db_sa
#     Found existing installation: ibm-db-sa 0.3.3
#     Uninstalling ibm-db-sa-0.3.3:
#       Successfully uninstalled ibm-db-sa-0.3.3
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# ...

# %%
# %load_ext sql

# %% [markdown]
# ##### Enter the connection string for your Db2 on Cloud database instance as shown below
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL

# %%
# @hidden_cell
# %sql ibm_db_sa://kfc13900:ZdDG0wBmKPpEAb1K@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb?security=SSL

# %% [markdown]
# #### Query the database system catalog to retrieve table metadata
# Verify that the table creation was successful by checking whether the CHICAGO_SCHOOLS_DATA table was created

# %%
# %sql select * from SYSCAT.TABLES where TABNAME = 'CHICAGO_SCHOOLS_DATA'
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('KFC13900', 'CHICAGO_SCHOOLS_DATA', 'KFC13900', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2022, 5, 14, 20, 56, 34, 86092), datetime.datetime(2022, 5, 14, 20, 56, 34, 86092), datetime.datetime(2022, 5, 14, 20, 56, 34, 86092), None, 78, 13, 350, -1, -1, -1, -1, -1, -1, -1, -1, 'KFC13900SPACE1', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, -1, 'N', 999, -1, -1.0, -1, -1.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', -1, datetime.datetime(2022, 5, 14, 20, 56, 34, 86092), 0, ' ', None, None, 'N', 'KFC13900', ' ', ' ', ' ', datetime.date(2022, 5, 17), ' ', 'N', 'R', 'N', -1.0, None)]

# %% [markdown]
# #### Query the database system catalog to retrieve column metadata

# %%
# Number of Elementary Schools in the dataset
# %sql SELECT COUNT(*) AS NUMBER_OF_ELEMENTARY_SCHOOLS \
 FROM CHICAGO_SCHOOLS_DATA \
  WHERE """Elementary, Middle, or High School""" = 'ES' ;
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [(462,)]

# %%
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_SCHOOLS_DATA'
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [(78,)]

# %%
# Retrieve the the list of columns in SCHOOLS table and their column type (datatype) and length

# %sql select distinct(NAME), COLTYPE, LENGTH from SYSIBM.SYSCOLUMNS where TBNAME = 'CHICAGO_SCHOOLS_DATA'
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('10th Grade PLAN (2009)', 'VARCHAR ', 4),
#  ('10th Grade PLAN (2010)', 'VARCHAR ', 4),
#  ('11th Grade Average ACT (2011)', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2009)', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2010)', 'VARCHAR ', 4),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE_', 'VARCHAR ', 3),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR ', 6),
#  ('AVERAGE_TEACHER_ATTENDANCE', 'VARCHAR ', 6),
#  ('CITY', 'VARCHAR ', 7),
#  ('COLLABORATIVE_NAME', 'VARCHAR ', 34),
#  ('COLLEGE_ELIGIBILITY__', 'VARCHAR ', 4),
#  ('COLLEGE_ENROLLMENT', 'SMALLINT', 2),
#  ('COLLEGE_ENROLLMENT_RATE__', 'VARCHAR ', 4),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR ', 22),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR ', 15),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR ', 16),
#  ('ENVIRONMENT_ICON', 'VARCHAR ', 11),
# ...

# %%
# Get the highest safety score
# %sql select MAX(Safety_Score) AS MAX_SAFETY_SCORE from CHICAGO_SCHOOLS_DATA
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [(99,)]

# %%
# Retrieve schools that have highest Safety Score
# %sql select Name_of_School, Safety_Score from CHICAGO_SCHOOLS_DATA where \
  Safety_Score= (select MAX(Safety_Score) from CHICAGO_SCHOOLS_DATA)
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('Abraham Lincoln Elementary School', 99),
#  ('Alexander Graham Bell Elementary School', 99),
#  ('Annie Keller Elementary Gifted Magnet School', 99),
#  ('Augustus H Burley Elementary School', 99),
#  ('Edgar Allan Poe Elementary Classical School', 99),
#  ('Edgebrook Elementary School', 99),
#  ('Ellen Mitchell Elementary School', 99),
#  ('James E McDade Elementary Classical School', 99),
#  ('James G Blaine Elementary School', 99),
#  ('LaSalle Elementary Language Academy', 99),
#  ('Mary E Courtenay Elementary Language Arts Center', 99),
#  ('Northside College Preparatory High School', 99),
#  ('Northside Learning Center High School', 99),
#  ('Norwood Park Elementary School', 99),
#  ('Oriole Park Elementary School', 99),
#  ('Sauganash Elementary School', 99),
#  ('Stephen Decatur Classical Elementary School', 99),
# ...

# %%
# Retrieve top 10 schools with the highest "Average Student Attendance"
# %sql select Name_of_School, Average_student_attendance from CHICAGO_SCHOOLS_DATA \
   order by Average_Student_Attendance desc nulls last limit 10
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %%
# Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance
# %sql select Name_of_School, Average_student_attendance from CHICAGO_SCHOOLS_DATA \
   order by Average_Student_Attendance asc nulls last limit 5
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %%
# Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance
# %sql select Name_of_School, Average_student_attendance from CHICAGO_SCHOOLS_DATA \
   order by Average_Student_Attendance fetch first 5 rows only
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %%
# Remove the '%' sign from the above result set for Average Student Attendance column

# %sql SELECT Name_of_School, REPLACE(Average_Student_Attendance, '%', '') \
     from CHICAGO_SCHOOLS_DATA  \
     order by Average_Student_Attendance \
     fetch first 5 rows only
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %%
# Retrieve schools which have Average Student Attendance lower than 70%?

# %sql SELECT Name_of_School, Average_Student_Attendance  \
     from CHICAGO_SCHOOLS_DATA  \
     where CAST ( REPLACE(Average_Student_Attendance, '%', '') AS DOUBLE ) < 70 \
     order by Average_Student_Attendance
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %%
# %sql SELECT Name_of_School, Average_Student_Attendance  \
     from CHICAGO_SCHOOLS_DATA \
     where DECIMAL ( REPLACE(Average_Student_Attendance, '%', '') ) < 70 \
     order by Average_Student_Attendance
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %%
# Get the total College Enrollment for each Community Area

# %sql select Community_Area_Name, sum(College_Enrollment) AS TOTAL_ENROLLMENT \
   from CHICAGO_SCHOOLS_DATA \
   group by Community_Area_Name \
    order by total_enrollment desc
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('SOUTH LAWNDALE', 14793),
#  ('BELMONT CRAGIN', 14386),
#  ('AUSTIN', 10933),
#  ('GAGE PARK', 9915),
#  ('BRIGHTON PARK', 9647),
#  ('WEST TOWN', 9429),
#  ('HUMBOLDT PARK', 8620),
#  ('WEST RIDGE', 8197),
#  ('NEAR WEST SIDE', 7975),
#  ('NEW CITY', 7922),
#  ('IRVING PARK', 7764),
#  ('NORTH CENTER', 7541),
#  ('LOGAN SQUARE', 7351),
#  ('LOWER WEST SIDE', 7257),
#  ('CHICAGO LAWN', 7086),
#  ('LAKE VIEW', 7055),
#  ('ROSELAND', 7020),
#  ('PORTAGE PARK', 6954),
#  ('ALBANY PARK', 6864),
#  ('ENGLEWOOD', 6832),
#  ('ASHBURN', 6483),
#  ('NORWOOD PARK', 6469),
#  ('WEST ENGLEWOOD', 5946),
#  ('LINCOLN PARK', 5615),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('NORTH LAWNDALE', 5146),
#  ('CHATHAM', 5042),
#  ('ARCHER HEIGHTS', 4823),
#  ('DOUGLAS', 4670),
#  ('EDGEWATER', 4600),
#  ('DUNNING', 4568),
#  ('GARFIELD RIDGE', 4552),
# ...

# %%
# Get the 5 Community Areas with the least total College Enrollment sorted in ascending order

# %sql select Community_Area_Name, sum(College_Enrollment) AS TOTAL_ENROLLMENT \
   from CHICAGO_SCHOOLS_DATA \
   group by Community_Area_Name \
    order by total_enrollment asc limit 5
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %%
# List 5 schools with lowest safety score.

# %sql SELECT name_of_school, safety_score \
FROM CHICAGO_SCHOOLS_DATA \
ORDER BY safety_score \
LIMIT 5
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('Edmond Burke Elementary School', 1),
#  ("Luke O'Toole Elementary School", 5),
#  ('George W Tilton Elementary School', 6),
#  ('Foster Park Elementary School', 11),
#  ('Emil G Hirsch Metropolitan High School', 13)]

# %%
# Get the hardship index for the community area which has College Enrollment of 4368
# NOTE:To get the solution the CHICAGO_SOCIOECONOMIC_DATA table should be in the database

# %sql SELECT community_area_name, HARDSHIP_INDEX \
     FROM CHICAGO_SOCIOECONOMIC_DATA \
      WHERE community_area_number  = (SELECT community_area_number FROM CHICAGO_SCHOOLS_DATA WHERE COLLEGE_ENROLLMENT = 4368 )
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('North Center', '6')]

# %%
# Get the hardship index for the community area which has the school with the highest enrollment.
# %sql select community_area_number, community_area_name, hardship_index from chicago_socioeconomic_data \
   where community_area_number in \
   ( select community_area_number from CHICAGO_SCHOOLS_DATA order by college_enrollment desc limit 1 )
# Out:
#  * ibm_db_sa://kfc13900:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/bludb
# Done.
# [('5', 'North Center', '6')]
